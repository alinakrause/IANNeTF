# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Task 01 - Building your data set

# %%
# random input numbers
x = np.random.rand(100)

# targets
f = lambda x: -x**3+x**2
#f = lambda x: np.sin(5*x)+1
t = f(x)

# putting it in one array
data = np.stack([x, t], axis=1)

# %%
# visualize datapoints
plt.scatter(x, t)
plt.xlabel('input')
plt.ylabel('target')
plt.show()

# %%
# relu activation function
def relu(x):
  x[x<0] = 0
  return x

# derivative of relu function
def relu_derivative(x):
  x[x>=0] = 1
  x[x<0] = 0 
  return x
  
# mean squared error function
def mse(y, t):
  return 1/2 * ((y - t)**2)

# %% [markdown]
# Task 02 - Perceptrons

# %%
# one perceptron layer
class Layer(object):

  # instanciated with number of units of this and preceding layer
  def __init__(self, n_units, input_units):
    self.bias = np.zeros(n_units)
    self.weights = np.random.rand(input_units, n_units)

    self.input = None
    self.preactivation = None
    self.activation = None

  # forward method for activation
  # returns each unit's activation
  def forward_step(self, input):
    self.input = input
    self.preactivation = input @ self.weights + self.bias
    self.activation = relu(self.preactivation)
    return self.activation

  # backwards method for backpropagation
  # calculates the gradients and 
  # updates each unit's parameters accordingly
  def backward_step(self, dLda, lr): # dLda = loss-activation derivative obtained from layer l+1 or directly from loss function derivative
    # compute gradients 
    error_signal = relu_derivative(self.preactivation) * dLda # bias gradients
    weights_grad = (np.transpose(self.input) @ error_signal) 
    new_dLda = error_signal @ np.transpose(self.weights)

    # update parameters
    self.weights = self.weights - (lr * weights_grad)
    self.bias = self.bias - (lr * error_signal)

    return new_dLda

# %% [markdown]
# Task 03 - Multi-Layer Perceptron

# %%
# whole multi-layer perceptron
class MLP(object):

  # instanciated with learning rate and a list unit sizes of all layers
  def __init__(self, lr, layers):
    self.lr = lr
    self.layers = []
    n_input = 1
    for n_units in layers:
       self.layers.append(Layer(n_units, n_input))
       n_input = n_units

  # forward propagation of one datapoint
  # returns output of the layer 
  def forward_step(self, data_point):
    layer_input = np.array([data_point[0]]).reshape(1,1)
    for layer in self.layers:
      layer_input = layer.forward_step(layer_input)
    return layer_input

  def backpropagation(self, data_point, prediction):
    dLda = prediction - data_point[1] # derivative for mse loss function
    for layer in reversed(self.layers):
      dLda = layer.backward_step(dLda, self.lr)

# %% [markdown]
# Task 04 - Training

# %%
# MLP with 1 hidden layer (10 units) & output layer (1 unit)
nn = MLP(lr=0.005, layers=[10, 1])

losses = [] # saves average loss of epoches
num_epochs = 1000
for epoch in range(num_epochs):
  print('Epoch {0}/{1}:'.format(epoch, num_epochs))
  epoch_losses = [] # saves losses of each data point prediction

  # perform forward and backward steps for each data point
  for data_point in data: 
    prediction = nn.forward_step(data_point)
    # compute mse loss function
    epoch_losses.append(mse(prediction, data_point[1])) 
    nn.backpropagation(data_point, prediction)

  avg_loss = np.mean(epoch_losses) 
  losses.append(avg_loss)
  print('Average Loss: %.6f'%(avg_loss))

print("Training finished.")
# Out:
# Epoch 0/1000:
# Average Loss: 0.151220
# Epoch 1/1000:
# Average Loss: 0.020586
# Epoch 2/1000:
# Average Loss: 0.010656
# Epoch 3/1000:
# Average Loss: 0.008343
# Epoch 4/1000:
# Average Loss: 0.007546
# Epoch 5/1000:
# Average Loss: 0.007178
# Epoch 6/1000:
# Average Loss: 0.006963
# Epoch 7/1000:
# Average Loss: 0.006808
# Epoch 8/1000:
# Average Loss: 0.006673
# Epoch 9/1000:
# Average Loss: 0.006540
# Epoch 10/1000:
# Average Loss: 0.006408
# Epoch 11/1000:
# Average Loss: 0.006280
# Epoch 12/1000:
# Average Loss: 0.006156
# Epoch 13/1000:
# Average Loss: 0.006030
# Epoch 14/1000:
# Average Loss: 0.005899
# Epoch 15/1000:
# Average Loss: 0.005771
# Epoch 16/1000:
# Average Loss: 0.005636
# Epoch 17/1000:
# Average Loss: 0.005494
# Epoch 18/1000:
# Average Loss: 0.005341
# Epoch 19/1000:
# Average Loss: 0.005188
# Epoch 20/1000:
# Average Loss: 0.005036
# Epoch 21/1000:
# Average Loss: 0.004888
# Epoch 22/1000:
# Average Loss: 0.004734
# Epoch 23/1000:
# Average Loss: 0.004571
# Epoch 24/1000:
# Average Loss: 0.004407
# Epoch 25/1000:
# Average Loss: 0.004236
# Epoch 26/1000:
# Average Loss: 0.004065
# Epoch 27/1000:
# Average Loss: 0.003899
# Epoch 28/1000:
# Average Loss: 0.003734
# Epoch 29/1000:
# Average Loss: 0.003570
# Epoch 30/1000:
# Average Loss: 0.003410
# Epoch 31/1000:
# Average Loss: 0.003249
# Epoch 32/1000:
# Average Loss: 0.003075
# Epoch 33/1000:
# Average Loss: 0.002909
# Epoch 34/1000:
# Average Loss: 0.002743
# Epoch 35/1000:
# Average Loss: 0.002578
# Epoch 36/1000:
# Average Loss: 0.002421
# Epoch 37/1000:
# Average Loss: 0.002270
# Epoch 38/1000:
# Average Loss: 0.002127
# Epoch 39/1000:
# Average Loss: 0.001991
# Epoch 40/1000:
# Average Loss: 0.001863
# Epoch 41/1000:
# Average Loss: 0.001741
# Epoch 42/1000:
# Average Loss: 0.001630
# Epoch 43/1000:
# Average Loss: 0.001527
# Epoch 44/1000:
# Average Loss: 0.001435
# Epoch 45/1000:
# Average Loss: 0.001350
# Epoch 46/1000:
# Average Loss: 0.001277
# Epoch 47/1000:
# Average Loss: 0.001216
# Epoch 48/1000:
# Average Loss: 0.001166
# Epoch 49/1000:
# Average Loss: 0.001125
# Epoch 50/1000:
# Average Loss: 0.001092
# Epoch 51/1000:
# Average Loss: 0.001066
# Epoch 52/1000:
# Average Loss: 0.001044
# Epoch 53/1000:
# Average Loss: 0.001027
# Epoch 54/1000:
# Average Loss: 0.001013
# Epoch 55/1000:
# Average Loss: 0.001001
# Epoch 56/1000:
# Average Loss: 0.000992
# Epoch 57/1000:
# Average Loss: 0.000984
# Epoch 58/1000:
# Average Loss: 0.000978
# Epoch 59/1000:
# Average Loss: 0.000973
# Epoch 60/1000:
# Average Loss: 0.000969
# Epoch 61/1000:
# Average Loss: 0.000966
# Epoch 62/1000:
# Average Loss: 0.000963
# Epoch 63/1000:
# Average Loss: 0.000961
# Epoch 64/1000:
# Average Loss: 0.000960
# Epoch 65/1000:
# Average Loss: 0.000958
# Epoch 66/1000:
# Average Loss: 0.000957
# Epoch 67/1000:
# Average Loss: 0.000956
# Epoch 68/1000:
# Average Loss: 0.000956
# Epoch 69/1000:
# Average Loss: 0.000955
# Epoch 70/1000:
# Average Loss: 0.000955
# Epoch 71/1000:
# Average Loss: 0.000954
# Epoch 72/1000:
# Average Loss: 0.000954
# Epoch 73/1000:
# Average Loss: 0.000954
# Epoch 74/1000:
# Average Loss: 0.000954
# Epoch 75/1000:
# Average Loss: 0.000953
# Epoch 76/1000:
# Average Loss: 0.000953
# Epoch 77/1000:
# Average Loss: 0.000953
# Epoch 78/1000:
# Average Loss: 0.000953
# Epoch 79/1000:
# Average Loss: 0.000953
# Epoch 80/1000:
# Average Loss: 0.000953
# Epoch 81/1000:
# Average Loss: 0.000953
# Epoch 82/1000:
# Average Loss: 0.000953
# Epoch 83/1000:
# Average Loss: 0.000953
# Epoch 84/1000:
# Average Loss: 0.000953
# Epoch 85/1000:
# Average Loss: 0.000953
# Epoch 86/1000:
# Average Loss: 0.000953
# Epoch 87/1000:
# Average Loss: 0.000953
# Epoch 88/1000:
# Average Loss: 0.000953
# Epoch 89/1000:
# Average Loss: 0.000953
# Epoch 90/1000:
# Average Loss: 0.000953
# Epoch 91/1000:
# Average Loss: 0.000953
# Epoch 92/1000:
# Average Loss: 0.000953
# Epoch 93/1000:
# Average Loss: 0.000953
# Epoch 94/1000:
# Average Loss: 0.000953
# Epoch 95/1000:
# Average Loss: 0.000953
# Epoch 96/1000:
# Average Loss: 0.000953
# Epoch 97/1000:
# Average Loss: 0.000953
# Epoch 98/1000:
# Average Loss: 0.000953
# Epoch 99/1000:
# Average Loss: 0.000953
# Epoch 100/1000:
# Average Loss: 0.000953
# Epoch 101/1000:
# Average Loss: 0.000953
# Epoch 102/1000:
# Average Loss: 0.000953
# Epoch 103/1000:
# Average Loss: 0.000953
# Epoch 104/1000:
# Average Loss: 0.000953
# Epoch 105/1000:
# Average Loss: 0.000953
# Epoch 106/1000:
# Average Loss: 0.000953
# Epoch 107/1000:
# Average Loss: 0.000953
# Epoch 108/1000:
# Average Loss: 0.000953
# Epoch 109/1000:
# Average Loss: 0.000953
# Epoch 110/1000:
# Average Loss: 0.000953
# Epoch 111/1000:
# Average Loss: 0.000953
# Epoch 112/1000:
# Average Loss: 0.000953
# Epoch 113/1000:
# Average Loss: 0.000953
# Epoch 114/1000:
# Average Loss: 0.000953
# Epoch 115/1000:
# Average Loss: 0.000953
# Epoch 116/1000:
# Average Loss: 0.000953
# Epoch 117/1000:
# Average Loss: 0.000953
# Epoch 118/1000:
# Average Loss: 0.000953
# Epoch 119/1000:
# Average Loss: 0.000953
# Epoch 120/1000:
# Average Loss: 0.000953
# Epoch 121/1000:
# Average Loss: 0.000953
# Epoch 122/1000:
# Average Loss: 0.000953
# Epoch 123/1000:
# Average Loss: 0.000953
# Epoch 124/1000:
# Average Loss: 0.000953
# Epoch 125/1000:
# Average Loss: 0.000953
# Epoch 126/1000:
# Average Loss: 0.000953
# Epoch 127/1000:
# Average Loss: 0.000953
# Epoch 128/1000:
# Average Loss: 0.000953
# Epoch 129/1000:
# Average Loss: 0.000953
# Epoch 130/1000:
# Average Loss: 0.000953
# Epoch 131/1000:
# Average Loss: 0.000953
# Epoch 132/1000:
# Average Loss: 0.000953
# Epoch 133/1000:
# Average Loss: 0.000953
# Epoch 134/1000:
# Average Loss: 0.000953
# Epoch 135/1000:
# Average Loss: 0.000953
# Epoch 136/1000:
# Average Loss: 0.000953
# Epoch 137/1000:
# Average Loss: 0.000953
# Epoch 138/1000:
# Average Loss: 0.000953
# Epoch 139/1000:
# Average Loss: 0.000953
# Epoch 140/1000:
# Average Loss: 0.000953
# Epoch 141/1000:
# Average Loss: 0.000953
# Epoch 142/1000:
# Average Loss: 0.000953
# Epoch 143/1000:
# Average Loss: 0.000953
# Epoch 144/1000:
# Average Loss: 0.000953
# Epoch 145/1000:
# Average Loss: 0.000953
# Epoch 146/1000:
# Average Loss: 0.000953
# Epoch 147/1000:
# Average Loss: 0.000953
# Epoch 148/1000:
# Average Loss: 0.000953
# Epoch 149/1000:
# Average Loss: 0.000953
# Epoch 150/1000:
# Average Loss: 0.000953
# Epoch 151/1000:
# Average Loss: 0.000953
# Epoch 152/1000:
# Average Loss: 0.000953
# Epoch 153/1000:
# Average Loss: 0.000953
# Epoch 154/1000:
# Average Loss: 0.000953
# Epoch 155/1000:
# Average Loss: 0.000953
# Epoch 156/1000:
# Average Loss: 0.000953
# Epoch 157/1000:
# Average Loss: 0.000953
# Epoch 158/1000:
# Average Loss: 0.000953
# Epoch 159/1000:
# Average Loss: 0.000953
# Epoch 160/1000:
# Average Loss: 0.000953
# Epoch 161/1000:
# Average Loss: 0.000953
# Epoch 162/1000:
# Average Loss: 0.000953
# Epoch 163/1000:
# Average Loss: 0.000953
# Epoch 164/1000:
# Average Loss: 0.000953
# Epoch 165/1000:
# Average Loss: 0.000953
# Epoch 166/1000:
# Average Loss: 0.000953
# Epoch 167/1000:
# Average Loss: 0.000953
# Epoch 168/1000:
# Average Loss: 0.000953
# Epoch 169/1000:
# Average Loss: 0.000953
# Epoch 170/1000:
# Average Loss: 0.000953
# Epoch 171/1000:
# Average Loss: 0.000953
# Epoch 172/1000:
# Average Loss: 0.000953
# Epoch 173/1000:
# Average Loss: 0.000953
# Epoch 174/1000:
# Average Loss: 0.000953
# Epoch 175/1000:
# Average Loss: 0.000953
# Epoch 176/1000:
# Average Loss: 0.000953
# Epoch 177/1000:
# Average Loss: 0.000953
# Epoch 178/1000:
# Average Loss: 0.000953
# Epoch 179/1000:
# Average Loss: 0.000953
# Epoch 180/1000:
# Average Loss: 0.000953
# Epoch 181/1000:
# Average Loss: 0.000953
# Epoch 182/1000:
# Average Loss: 0.000953
# Epoch 183/1000:
# Average Loss: 0.000953
# Epoch 184/1000:
# Average Loss: 0.000953
# Epoch 185/1000:
# Average Loss: 0.000953
# Epoch 186/1000:
# Average Loss: 0.000953
# Epoch 187/1000:
# Average Loss: 0.000953
# Epoch 188/1000:
# Average Loss: 0.000953
# Epoch 189/1000:
# Average Loss: 0.000953
# Epoch 190/1000:
# Average Loss: 0.000953
# Epoch 191/1000:
# Average Loss: 0.000953
# Epoch 192/1000:
# Average Loss: 0.000953
# Epoch 193/1000:
# Average Loss: 0.000953
# Epoch 194/1000:
# Average Loss: 0.000953
# Epoch 195/1000:
# Average Loss: 0.000953
# Epoch 196/1000:
# Average Loss: 0.000953
# Epoch 197/1000:
# Average Loss: 0.000953
# Epoch 198/1000:
# Average Loss: 0.000953
# Epoch 199/1000:
# Average Loss: 0.000953
# Epoch 200/1000:
# Average Loss: 0.000953
# Epoch 201/1000:
# Average Loss: 0.000953
# Epoch 202/1000:
# Average Loss: 0.000953
# Epoch 203/1000:
# Average Loss: 0.000953
# Epoch 204/1000:
# Average Loss: 0.000953
# Epoch 205/1000:
# Average Loss: 0.000953
# Epoch 206/1000:
# Average Loss: 0.000953
# Epoch 207/1000:
# Average Loss: 0.000953
# Epoch 208/1000:
# Average Loss: 0.000953
# Epoch 209/1000:
# Average Loss: 0.000953
# Epoch 210/1000:
# Average Loss: 0.000953
# Epoch 211/1000:
# Average Loss: 0.000953
# Epoch 212/1000:
# Average Loss: 0.000953
# Epoch 213/1000:
# Average Loss: 0.000953
# Epoch 214/1000:
# Average Loss: 0.000953
# Epoch 215/1000:
# Average Loss: 0.000953
# Epoch 216/1000:
# Average Loss: 0.000953
# Epoch 217/1000:
# Average Loss: 0.000953
# Epoch 218/1000:
# Average Loss: 0.000953
# Epoch 219/1000:
# Average Loss: 0.000953
# Epoch 220/1000:
# Average Loss: 0.000953
# Epoch 221/1000:
# Average Loss: 0.000953
# Epoch 222/1000:
# Average Loss: 0.000953
# Epoch 223/1000:
# Average Loss: 0.000953
# Epoch 224/1000:
# Average Loss: 0.000953
# Epoch 225/1000:
# Average Loss: 0.000953
# Epoch 226/1000:
# Average Loss: 0.000953
# Epoch 227/1000:
# Average Loss: 0.000953
# Epoch 228/1000:
# Average Loss: 0.000953
# Epoch 229/1000:
# Average Loss: 0.000953
# Epoch 230/1000:
# Average Loss: 0.000953
# Epoch 231/1000:
# Average Loss: 0.000953
# Epoch 232/1000:
# Average Loss: 0.000953
# Epoch 233/1000:
# Average Loss: 0.000953
# Epoch 234/1000:
# Average Loss: 0.000953
# Epoch 235/1000:
# Average Loss: 0.000953
# Epoch 236/1000:
# Average Loss: 0.000953
# Epoch 237/1000:
# Average Loss: 0.000953
# Epoch 238/1000:
# Average Loss: 0.000953
# Epoch 239/1000:
# Average Loss: 0.000953
# Epoch 240/1000:
# Average Loss: 0.000953
# Epoch 241/1000:
# Average Loss: 0.000953
# Epoch 242/1000:
# Average Loss: 0.000953
# Epoch 243/1000:
# Average Loss: 0.000953
# Epoch 244/1000:
# Average Loss: 0.000953
# Epoch 245/1000:
# Average Loss: 0.000953
# Epoch 246/1000:
# Average Loss: 0.000953
# Epoch 247/1000:
# Average Loss: 0.000953
# Epoch 248/1000:
# Average Loss: 0.000953
# Epoch 249/1000:
# Average Loss: 0.000953
# Epoch 250/1000:
# Average Loss: 0.000953
# Epoch 251/1000:
# Average Loss: 0.000953
# Epoch 252/1000:
# Average Loss: 0.000953
# Epoch 253/1000:
# Average Loss: 0.000953
# Epoch 254/1000:
# Average Loss: 0.000953
# Epoch 255/1000:
# Average Loss: 0.000953
# Epoch 256/1000:
# Average Loss: 0.000953
# Epoch 257/1000:
# Average Loss: 0.000953
# Epoch 258/1000:
# Average Loss: 0.000953
# Epoch 259/1000:
# Average Loss: 0.000953
# Epoch 260/1000:
# Average Loss: 0.000953
# Epoch 261/1000:
# Average Loss: 0.000953
# Epoch 262/1000:
# Average Loss: 0.000953
# Epoch 263/1000:
# Average Loss: 0.000953
# Epoch 264/1000:
# Average Loss: 0.000953
# Epoch 265/1000:
# Average Loss: 0.000953
# Epoch 266/1000:
# Average Loss: 0.000953
# Epoch 267/1000:
# Average Loss: 0.000953
# Epoch 268/1000:
# Average Loss: 0.000953
# Epoch 269/1000:
# Average Loss: 0.000953
# Epoch 270/1000:
# Average Loss: 0.000953
# Epoch 271/1000:
# Average Loss: 0.000953
# Epoch 272/1000:
# Average Loss: 0.000953
# Epoch 273/1000:
# Average Loss: 0.000953
# Epoch 274/1000:
# Average Loss: 0.000953
# Epoch 275/1000:
# Average Loss: 0.000953
# Epoch 276/1000:
# Average Loss: 0.000953
# Epoch 277/1000:
# Average Loss: 0.000953
# Epoch 278/1000:
# Average Loss: 0.000953
# Epoch 279/1000:
# Average Loss: 0.000953
# Epoch 280/1000:
# Average Loss: 0.000953
# Epoch 281/1000:
# Average Loss: 0.000953
# Epoch 282/1000:
# Average Loss: 0.000953
# Epoch 283/1000:
# Average Loss: 0.000953
# Epoch 284/1000:
# Average Loss: 0.000953
# Epoch 285/1000:
# Average Loss: 0.000953
# Epoch 286/1000:
# Average Loss: 0.000953
# Epoch 287/1000:
# Average Loss: 0.000953
# Epoch 288/1000:
# Average Loss: 0.000953
# Epoch 289/1000:
# Average Loss: 0.000953
# Epoch 290/1000:
# Average Loss: 0.000953
# Epoch 291/1000:
# Average Loss: 0.000953
# Epoch 292/1000:
# Average Loss: 0.000953
# Epoch 293/1000:
# Average Loss: 0.000953
# Epoch 294/1000:
# Average Loss: 0.000953
# Epoch 295/1000:
# Average Loss: 0.000953
# Epoch 296/1000:
# Average Loss: 0.000953
# Epoch 297/1000:
# Average Loss: 0.000953
# Epoch 298/1000:
# Average Loss: 0.000953
# Epoch 299/1000:
# Average Loss: 0.000953
# Epoch 300/1000:
# Average Loss: 0.000953
# Epoch 301/1000:
# Average Loss: 0.000953
# Epoch 302/1000:
# Average Loss: 0.000953
# Epoch 303/1000:
# Average Loss: 0.000953
# Epoch 304/1000:
# Average Loss: 0.000953
# Epoch 305/1000:
# Average Loss: 0.000953
# Epoch 306/1000:
# Average Loss: 0.000953
# Epoch 307/1000:
# Average Loss: 0.000953
# Epoch 308/1000:
# Average Loss: 0.000953
# Epoch 309/1000:
# Average Loss: 0.000953
# Epoch 310/1000:
# Average Loss: 0.000953
# Epoch 311/1000:
# Average Loss: 0.000953
# Epoch 312/1000:
# Average Loss: 0.000953
# Epoch 313/1000:
# Average Loss: 0.000953
# Epoch 314/1000:
# Average Loss: 0.000953
# Epoch 315/1000:
# Average Loss: 0.000953
# Epoch 316/1000:
# Average Loss: 0.000953
# Epoch 317/1000:
# Average Loss: 0.000953
# Epoch 318/1000:
# Average Loss: 0.000953
# Epoch 319/1000:
# Average Loss: 0.000953
# Epoch 320/1000:
# Average Loss: 0.000953
# Epoch 321/1000:
# Average Loss: 0.000953
# Epoch 322/1000:
# Average Loss: 0.000953
# Epoch 323/1000:
# Average Loss: 0.000953
# Epoch 324/1000:
# Average Loss: 0.000953
# Epoch 325/1000:
# Average Loss: 0.000953
# Epoch 326/1000:
# Average Loss: 0.000953
# Epoch 327/1000:
# Average Loss: 0.000953
# Epoch 328/1000:
# Average Loss: 0.000953
# Epoch 329/1000:
# Average Loss: 0.000953
# Epoch 330/1000:
# Average Loss: 0.000953
# Epoch 331/1000:
# Average Loss: 0.000953
# Epoch 332/1000:
# Average Loss: 0.000953
# Epoch 333/1000:
# Average Loss: 0.000953
# Epoch 334/1000:
# Average Loss: 0.000953
# Epoch 335/1000:
# Average Loss: 0.000953
# Epoch 336/1000:
# Average Loss: 0.000953
# Epoch 337/1000:
# Average Loss: 0.000953
# Epoch 338/1000:
# Average Loss: 0.000953
# Epoch 339/1000:
# Average Loss: 0.000953
# Epoch 340/1000:
# Average Loss: 0.000953
# Epoch 341/1000:
# Average Loss: 0.000953
# Epoch 342/1000:
# Average Loss: 0.000953
# Epoch 343/1000:
# Average Loss: 0.000953
# Epoch 344/1000:
# Average Loss: 0.000953
# Epoch 345/1000:
# Average Loss: 0.000953
# Epoch 346/1000:
# Average Loss: 0.000953
# Epoch 347/1000:
# Average Loss: 0.000953
# Epoch 348/1000:
# Average Loss: 0.000953
# Epoch 349/1000:
# Average Loss: 0.000953
# Epoch 350/1000:
# Average Loss: 0.000953
# Epoch 351/1000:
# Average Loss: 0.000953
# Epoch 352/1000:
# Average Loss: 0.000953
# Epoch 353/1000:
# Average Loss: 0.000953
# Epoch 354/1000:
# Average Loss: 0.000953
# Epoch 355/1000:
# Average Loss: 0.000953
# Epoch 356/1000:
# Average Loss: 0.000953
# Epoch 357/1000:
# Average Loss: 0.000953
# Epoch 358/1000:
# Average Loss: 0.000953
# Epoch 359/1000:
# Average Loss: 0.000953
# Epoch 360/1000:
# Average Loss: 0.000953
# Epoch 361/1000:
# Average Loss: 0.000953
# Epoch 362/1000:
# Average Loss: 0.000953
# Epoch 363/1000:
# Average Loss: 0.000953
# Epoch 364/1000:
# Average Loss: 0.000953
# Epoch 365/1000:
# Average Loss: 0.000953
# Epoch 366/1000:
# Average Loss: 0.000953
# Epoch 367/1000:
# Average Loss: 0.000953
# Epoch 368/1000:
# Average Loss: 0.000953
# Epoch 369/1000:
# Average Loss: 0.000953
# Epoch 370/1000:
# Average Loss: 0.000953
# Epoch 371/1000:
# Average Loss: 0.000953
# Epoch 372/1000:
# Average Loss: 0.000953
# Epoch 373/1000:
# Average Loss: 0.000953
# Epoch 374/1000:
# Average Loss: 0.000953
# Epoch 375/1000:
# Average Loss: 0.000953
# Epoch 376/1000:
# Average Loss: 0.000953
# Epoch 377/1000:
# Average Loss: 0.000953
# Epoch 378/1000:
# Average Loss: 0.000953
# Epoch 379/1000:
# Average Loss: 0.000953
# Epoch 380/1000:
# Average Loss: 0.000953
# Epoch 381/1000:
# Average Loss: 0.000953
# Epoch 382/1000:
# Average Loss: 0.000953
# Epoch 383/1000:
# Average Loss: 0.000953
# Epoch 384/1000:
# Average Loss: 0.000953
# Epoch 385/1000:
# Average Loss: 0.000953
# Epoch 386/1000:
# Average Loss: 0.000953
# Epoch 387/1000:
# Average Loss: 0.000953
# Epoch 388/1000:
# Average Loss: 0.000953
# Epoch 389/1000:
# Average Loss: 0.000953
# Epoch 390/1000:
# Average Loss: 0.000953
# Epoch 391/1000:
# Average Loss: 0.000953
# Epoch 392/1000:
# Average Loss: 0.000953
# Epoch 393/1000:
# Average Loss: 0.000953
# Epoch 394/1000:
# Average Loss: 0.000953
# Epoch 395/1000:
# Average Loss: 0.000953
# Epoch 396/1000:
# Average Loss: 0.000953
# Epoch 397/1000:
# Average Loss: 0.000953
# Epoch 398/1000:
# Average Loss: 0.000953
# Epoch 399/1000:
# Average Loss: 0.000953
# Epoch 400/1000:
# Average Loss: 0.000953
# Epoch 401/1000:
# Average Loss: 0.000953
# Epoch 402/1000:
# Average Loss: 0.000953
# Epoch 403/1000:
# Average Loss: 0.000953
# Epoch 404/1000:
# Average Loss: 0.000953
# Epoch 405/1000:
# Average Loss: 0.000953
# Epoch 406/1000:
# Average Loss: 0.000953
# Epoch 407/1000:
# Average Loss: 0.000953
# Epoch 408/1000:
# Average Loss: 0.000953
# Epoch 409/1000:
# Average Loss: 0.000953
# Epoch 410/1000:
# Average Loss: 0.000953
# Epoch 411/1000:
# Average Loss: 0.000953
# Epoch 412/1000:
# Average Loss: 0.000953
# Epoch 413/1000:
# Average Loss: 0.000953
# Epoch 414/1000:
# Average Loss: 0.000953
# Epoch 415/1000:
# Average Loss: 0.000953
# Epoch 416/1000:
# Average Loss: 0.000953
# Epoch 417/1000:
# Average Loss: 0.000953
# Epoch 418/1000:
# Average Loss: 0.000953
# Epoch 419/1000:
# Average Loss: 0.000953
# Epoch 420/1000:
# Average Loss: 0.000953
# Epoch 421/1000:
# Average Loss: 0.000953
# Epoch 422/1000:
# Average Loss: 0.000953
# Epoch 423/1000:
# Average Loss: 0.000953
# Epoch 424/1000:
# Average Loss: 0.000953
# Epoch 425/1000:
# Average Loss: 0.000953
# Epoch 426/1000:
# Average Loss: 0.000953
# Epoch 427/1000:
# Average Loss: 0.000953
# Epoch 428/1000:
# Average Loss: 0.000953
# Epoch 429/1000:
# Average Loss: 0.000953
# Epoch 430/1000:
# Average Loss: 0.000953
# Epoch 431/1000:
# Average Loss: 0.000953
# Epoch 432/1000:
# Average Loss: 0.000953
# Epoch 433/1000:
# Average Loss: 0.000953
# Epoch 434/1000:
# Average Loss: 0.000953
# Epoch 435/1000:
# Average Loss: 0.000953
# Epoch 436/1000:
# Average Loss: 0.000953
# Epoch 437/1000:
# Average Loss: 0.000953
# Epoch 438/1000:
# Average Loss: 0.000953
# Epoch 439/1000:
# Average Loss: 0.000953
# Epoch 440/1000:
# Average Loss: 0.000953
# Epoch 441/1000:
# Average Loss: 0.000953
# Epoch 442/1000:
# Average Loss: 0.000953
# Epoch 443/1000:
# Average Loss: 0.000953
# Epoch 444/1000:
# Average Loss: 0.000953
# Epoch 445/1000:
# Average Loss: 0.000953
# Epoch 446/1000:
# Average Loss: 0.000953
# Epoch 447/1000:
# Average Loss: 0.000953
# Epoch 448/1000:
# Average Loss: 0.000953
# Epoch 449/1000:
# Average Loss: 0.000953
# Epoch 450/1000:
# Average Loss: 0.000953
# Epoch 451/1000:
# Average Loss: 0.000953
# Epoch 452/1000:
# Average Loss: 0.000953
# Epoch 453/1000:
# Average Loss: 0.000953
# Epoch 454/1000:
# Average Loss: 0.000953
# Epoch 455/1000:
# Average Loss: 0.000953
# Epoch 456/1000:
# Average Loss: 0.000953
# Epoch 457/1000:
# Average Loss: 0.000953
# Epoch 458/1000:
# Average Loss: 0.000953
# Epoch 459/1000:
# Average Loss: 0.000953
# Epoch 460/1000:
# Average Loss: 0.000953
# Epoch 461/1000:
# Average Loss: 0.000953
# Epoch 462/1000:
# Average Loss: 0.000953
# Epoch 463/1000:
# Average Loss: 0.000953
# Epoch 464/1000:
# Average Loss: 0.000953
# Epoch 465/1000:
# Average Loss: 0.000953
# Epoch 466/1000:
# Average Loss: 0.000953
# Epoch 467/1000:
# Average Loss: 0.000953
# Epoch 468/1000:
# Average Loss: 0.000953
# Epoch 469/1000:
# Average Loss: 0.000953
# Epoch 470/1000:
# Average Loss: 0.000953
# Epoch 471/1000:
# Average Loss: 0.000953
# Epoch 472/1000:
# Average Loss: 0.000953
# Epoch 473/1000:
# Average Loss: 0.000953
# Epoch 474/1000:
# Average Loss: 0.000953
# Epoch 475/1000:
# Average Loss: 0.000953
# Epoch 476/1000:
# Average Loss: 0.000953
# Epoch 477/1000:
# Average Loss: 0.000953
# Epoch 478/1000:
# Average Loss: 0.000953
# Epoch 479/1000:
# Average Loss: 0.000953
# Epoch 480/1000:
# Average Loss: 0.000953
# Epoch 481/1000:
# Average Loss: 0.000953
# Epoch 482/1000:
# Average Loss: 0.000953
# Epoch 483/1000:
# Average Loss: 0.000953
# Epoch 484/1000:
# Average Loss: 0.000953
# Epoch 485/1000:
# Average Loss: 0.000953
# Epoch 486/1000:
# Average Loss: 0.000953
# Epoch 487/1000:
# Average Loss: 0.000953
# Epoch 488/1000:
# Average Loss: 0.000953
# Epoch 489/1000:
# Average Loss: 0.000953
# Epoch 490/1000:
# Average Loss: 0.000953
# Epoch 491/1000:
# Average Loss: 0.000953
# Epoch 492/1000:
# Average Loss: 0.000953
# Epoch 493/1000:
# Average Loss: 0.000953
# Epoch 494/1000:
# Average Loss: 0.000953
# Epoch 495/1000:
# Average Loss: 0.000953
# Epoch 496/1000:
# Average Loss: 0.000953
# Epoch 497/1000:
# Average Loss: 0.000953
# Epoch 498/1000:
# Average Loss: 0.000953
# Epoch 499/1000:
# Average Loss: 0.000953
# Epoch 500/1000:
# Average Loss: 0.000953
# Epoch 501/1000:
# Average Loss: 0.000953
# Epoch 502/1000:
# Average Loss: 0.000953
# Epoch 503/1000:
# Average Loss: 0.000953
# Epoch 504/1000:
# Average Loss: 0.000953
# Epoch 505/1000:
# Average Loss: 0.000953
# Epoch 506/1000:
# Average Loss: 0.000953
# Epoch 507/1000:
# Average Loss: 0.000953
# Epoch 508/1000:
# Average Loss: 0.000953
# Epoch 509/1000:
# Average Loss: 0.000953
# Epoch 510/1000:
# Average Loss: 0.000953
# Epoch 511/1000:
# Average Loss: 0.000953
# Epoch 512/1000:
# Average Loss: 0.000953
# Epoch 513/1000:
# Average Loss: 0.000953
# Epoch 514/1000:
# Average Loss: 0.000953
# Epoch 515/1000:
# Average Loss: 0.000953
# Epoch 516/1000:
# Average Loss: 0.000953
# Epoch 517/1000:
# Average Loss: 0.000953
# Epoch 518/1000:
# Average Loss: 0.000953
# Epoch 519/1000:
# Average Loss: 0.000953
# Epoch 520/1000:
# Average Loss: 0.000953
# Epoch 521/1000:
# Average Loss: 0.000953
# Epoch 522/1000:
# Average Loss: 0.000953
# Epoch 523/1000:
# Average Loss: 0.000953
# Epoch 524/1000:
# Average Loss: 0.000953
# Epoch 525/1000:
# Average Loss: 0.000953
# Epoch 526/1000:
# Average Loss: 0.000953
# Epoch 527/1000:
# Average Loss: 0.000953
# Epoch 528/1000:
# Average Loss: 0.000953
# Epoch 529/1000:
# Average Loss: 0.000953
# Epoch 530/1000:
# Average Loss: 0.000953
# Epoch 531/1000:
# Average Loss: 0.000953
# Epoch 532/1000:
# Average Loss: 0.000953
# Epoch 533/1000:
# Average Loss: 0.000953
# Epoch 534/1000:
# Average Loss: 0.000953
# Epoch 535/1000:
# Average Loss: 0.000953
# Epoch 536/1000:
# Average Loss: 0.000953
# Epoch 537/1000:
# Average Loss: 0.000953
# Epoch 538/1000:
# Average Loss: 0.000953
# Epoch 539/1000:
# Average Loss: 0.000953
# Epoch 540/1000:
# Average Loss: 0.000953
# Epoch 541/1000:
# Average Loss: 0.000953
# Epoch 542/1000:
# Average Loss: 0.000953
# Epoch 543/1000:
# Average Loss: 0.000953
# Epoch 544/1000:
# Average Loss: 0.000953
# Epoch 545/1000:
# Average Loss: 0.000953
# Epoch 546/1000:
# Average Loss: 0.000953
# Epoch 547/1000:
# Average Loss: 0.000953
# Epoch 548/1000:
# Average Loss: 0.000953
# Epoch 549/1000:
# Average Loss: 0.000953
# Epoch 550/1000:
# Average Loss: 0.000953
# Epoch 551/1000:
# Average Loss: 0.000953
# Epoch 552/1000:
# Average Loss: 0.000953
# Epoch 553/1000:
# Average Loss: 0.000953
# Epoch 554/1000:
# Average Loss: 0.000953
# Epoch 555/1000:
# Average Loss: 0.000953
# Epoch 556/1000:
# Average Loss: 0.000953
# Epoch 557/1000:
# Average Loss: 0.000953
# Epoch 558/1000:
# Average Loss: 0.000953
# Epoch 559/1000:
# Average Loss: 0.000953
# Epoch 560/1000:
# Average Loss: 0.000953
# Epoch 561/1000:
# Average Loss: 0.000953
# Epoch 562/1000:
# Average Loss: 0.000953
# Epoch 563/1000:
# Average Loss: 0.000953
# Epoch 564/1000:
# Average Loss: 0.000953
# Epoch 565/1000:
# Average Loss: 0.000953
# Epoch 566/1000:
# Average Loss: 0.000953
# Epoch 567/1000:
# Average Loss: 0.000953
# Epoch 568/1000:
# Average Loss: 0.000953
# Epoch 569/1000:
# Average Loss: 0.000953
# Epoch 570/1000:
# Average Loss: 0.000953
# Epoch 571/1000:
# Average Loss: 0.000953
# Epoch 572/1000:
# Average Loss: 0.000953
# Epoch 573/1000:
# Average Loss: 0.000953
# Epoch 574/1000:
# Average Loss: 0.000953
# Epoch 575/1000:
# Average Loss: 0.000953
# Epoch 576/1000:
# Average Loss: 0.000953
# Epoch 577/1000:
# Average Loss: 0.000953
# Epoch 578/1000:
# Average Loss: 0.000953
# Epoch 579/1000:
# Average Loss: 0.000953
# Epoch 580/1000:
# Average Loss: 0.000953
# Epoch 581/1000:
# Average Loss: 0.000953
# Epoch 582/1000:
# Average Loss: 0.000953
# Epoch 583/1000:
# Average Loss: 0.000953
# Epoch 584/1000:
# Average Loss: 0.000953
# Epoch 585/1000:
# Average Loss: 0.000953
# Epoch 586/1000:
# Average Loss: 0.000953
# Epoch 587/1000:
# Average Loss: 0.000953
# Epoch 588/1000:
# Average Loss: 0.000953
# Epoch 589/1000:
# Average Loss: 0.000953
# Epoch 590/1000:
# Average Loss: 0.000953
# Epoch 591/1000:
# Average Loss: 0.000953
# Epoch 592/1000:
# Average Loss: 0.000953
# Epoch 593/1000:
# Average Loss: 0.000953
# Epoch 594/1000:
# Average Loss: 0.000953
# Epoch 595/1000:
# Average Loss: 0.000953
# Epoch 596/1000:
# Average Loss: 0.000953
# Epoch 597/1000:
# Average Loss: 0.000953
# Epoch 598/1000:
# Average Loss: 0.000953
# Epoch 599/1000:
# Average Loss: 0.000953
# Epoch 600/1000:
# Average Loss: 0.000953
# Epoch 601/1000:
# Average Loss: 0.000953
# Epoch 602/1000:
# Average Loss: 0.000953
# Epoch 603/1000:
# Average Loss: 0.000953
# Epoch 604/1000:
# Average Loss: 0.000953
# Epoch 605/1000:
# Average Loss: 0.000953
# Epoch 606/1000:
# Average Loss: 0.000953
# Epoch 607/1000:
# Average Loss: 0.000953
# Epoch 608/1000:
# Average Loss: 0.000953
# Epoch 609/1000:
# Average Loss: 0.000953
# Epoch 610/1000:
# Average Loss: 0.000953
# Epoch 611/1000:
# Average Loss: 0.000953
# Epoch 612/1000:
# Average Loss: 0.000953
# Epoch 613/1000:
# Average Loss: 0.000953
# Epoch 614/1000:
# Average Loss: 0.000953
# Epoch 615/1000:
# Average Loss: 0.000953
# Epoch 616/1000:
# Average Loss: 0.000953
# Epoch 617/1000:
# Average Loss: 0.000953
# Epoch 618/1000:
# Average Loss: 0.000953
# Epoch 619/1000:
# Average Loss: 0.000953
# Epoch 620/1000:
# Average Loss: 0.000953
# Epoch 621/1000:
# Average Loss: 0.000953
# Epoch 622/1000:
# Average Loss: 0.000953
# Epoch 623/1000:
# Average Loss: 0.000953
# Epoch 624/1000:
# Average Loss: 0.000953
# Epoch 625/1000:
# Average Loss: 0.000953
# Epoch 626/1000:
# Average Loss: 0.000953
# Epoch 627/1000:
# Average Loss: 0.000953
# Epoch 628/1000:
# Average Loss: 0.000953
# Epoch 629/1000:
# Average Loss: 0.000953
# Epoch 630/1000:
# Average Loss: 0.000953
# Epoch 631/1000:
# Average Loss: 0.000953
# Epoch 632/1000:
# Average Loss: 0.000953
# Epoch 633/1000:
# Average Loss: 0.000953
# Epoch 634/1000:
# Average Loss: 0.000953
# Epoch 635/1000:
# Average Loss: 0.000953
# Epoch 636/1000:
# Average Loss: 0.000953
# Epoch 637/1000:
# Average Loss: 0.000953
# Epoch 638/1000:
# Average Loss: 0.000953
# Epoch 639/1000:
# Average Loss: 0.000953
# Epoch 640/1000:
# Average Loss: 0.000953
# Epoch 641/1000:
# Average Loss: 0.000953
# Epoch 642/1000:
# Average Loss: 0.000953
# Epoch 643/1000:
# Average Loss: 0.000953
# Epoch 644/1000:
# Average Loss: 0.000953
# Epoch 645/1000:
# Average Loss: 0.000953
# Epoch 646/1000:
# Average Loss: 0.000953
# Epoch 647/1000:
# Average Loss: 0.000953
# Epoch 648/1000:
# Average Loss: 0.000953
# Epoch 649/1000:
# Average Loss: 0.000953
# Epoch 650/1000:
# Average Loss: 0.000953
# Epoch 651/1000:
# Average Loss: 0.000953
# Epoch 652/1000:
# Average Loss: 0.000953
# Epoch 653/1000:
# Average Loss: 0.000953
# Epoch 654/1000:
# Average Loss: 0.000953
# Epoch 655/1000:
# Average Loss: 0.000953
# Epoch 656/1000:
# Average Loss: 0.000953
# Epoch 657/1000:
# Average Loss: 0.000953
# Epoch 658/1000:
# Average Loss: 0.000953
# Epoch 659/1000:
# Average Loss: 0.000953
# Epoch 660/1000:
# Average Loss: 0.000953
# Epoch 661/1000:
# Average Loss: 0.000953
# Epoch 662/1000:
# Average Loss: 0.000953
# Epoch 663/1000:
# Average Loss: 0.000953
# Epoch 664/1000:
# Average Loss: 0.000953
# Epoch 665/1000:
# Average Loss: 0.000953
# Epoch 666/1000:
# Average Loss: 0.000953
# Epoch 667/1000:
# Average Loss: 0.000953
# Epoch 668/1000:
# Average Loss: 0.000953
# Epoch 669/1000:
# Average Loss: 0.000953
# Epoch 670/1000:
# Average Loss: 0.000953
# Epoch 671/1000:
# Average Loss: 0.000953
# Epoch 672/1000:
# Average Loss: 0.000953
# Epoch 673/1000:
# Average Loss: 0.000953
# Epoch 674/1000:
# Average Loss: 0.000953
# Epoch 675/1000:
# Average Loss: 0.000953
# Epoch 676/1000:
# Average Loss: 0.000953
# Epoch 677/1000:
# Average Loss: 0.000953
# Epoch 678/1000:
# Average Loss: 0.000953
# Epoch 679/1000:
# Average Loss: 0.000953
# Epoch 680/1000:
# Average Loss: 0.000953
# Epoch 681/1000:
# Average Loss: 0.000953
# Epoch 682/1000:
# Average Loss: 0.000953
# Epoch 683/1000:
# Average Loss: 0.000953
# Epoch 684/1000:
# Average Loss: 0.000953
# Epoch 685/1000:
# Average Loss: 0.000953
# Epoch 686/1000:
# Average Loss: 0.000953
# Epoch 687/1000:
# Average Loss: 0.000953
# Epoch 688/1000:
# Average Loss: 0.000953
# Epoch 689/1000:
# Average Loss: 0.000953
# Epoch 690/1000:
# Average Loss: 0.000953
# Epoch 691/1000:
# Average Loss: 0.000953
# Epoch 692/1000:
# Average Loss: 0.000953
# Epoch 693/1000:
# Average Loss: 0.000953
# Epoch 694/1000:
# Average Loss: 0.000953
# Epoch 695/1000:
# Average Loss: 0.000953
# Epoch 696/1000:
# Average Loss: 0.000953
# Epoch 697/1000:
# Average Loss: 0.000953
# Epoch 698/1000:
# Average Loss: 0.000953
# Epoch 699/1000:
# Average Loss: 0.000953
# Epoch 700/1000:
# Average Loss: 0.000953
# Epoch 701/1000:
# Average Loss: 0.000953
# Epoch 702/1000:
# Average Loss: 0.000953
# Epoch 703/1000:
# Average Loss: 0.000953
# Epoch 704/1000:
# Average Loss: 0.000953
# Epoch 705/1000:
# Average Loss: 0.000953
# Epoch 706/1000:
# Average Loss: 0.000953
# Epoch 707/1000:
# Average Loss: 0.000953
# Epoch 708/1000:
# Average Loss: 0.000953
# Epoch 709/1000:
# Average Loss: 0.000953
# Epoch 710/1000:
# Average Loss: 0.000953
# Epoch 711/1000:
# Average Loss: 0.000953
# Epoch 712/1000:
# Average Loss: 0.000953
# Epoch 713/1000:
# Average Loss: 0.000953
# Epoch 714/1000:
# Average Loss: 0.000953
# Epoch 715/1000:
# Average Loss: 0.000953
# Epoch 716/1000:
# Average Loss: 0.000953
# Epoch 717/1000:
# Average Loss: 0.000953
# Epoch 718/1000:
# Average Loss: 0.000953
# Epoch 719/1000:
# Average Loss: 0.000953
# Epoch 720/1000:
# Average Loss: 0.000953
# Epoch 721/1000:
# Average Loss: 0.000953
# Epoch 722/1000:
# Average Loss: 0.000953
# Epoch 723/1000:
# Average Loss: 0.000953
# Epoch 724/1000:
# Average Loss: 0.000953
# Epoch 725/1000:
# Average Loss: 0.000953
# Epoch 726/1000:
# Average Loss: 0.000953
# Epoch 727/1000:
# Average Loss: 0.000953
# Epoch 728/1000:
# Average Loss: 0.000953
# Epoch 729/1000:
# Average Loss: 0.000953
# Epoch 730/1000:
# Average Loss: 0.000953
# Epoch 731/1000:
# Average Loss: 0.000953
# Epoch 732/1000:
# Average Loss: 0.000953
# Epoch 733/1000:
# Average Loss: 0.000953
# Epoch 734/1000:
# Average Loss: 0.000953
# Epoch 735/1000:
# Average Loss: 0.000953
# Epoch 736/1000:
# Average Loss: 0.000953
# Epoch 737/1000:
# Average Loss: 0.000953
# Epoch 738/1000:
# Average Loss: 0.000953
# Epoch 739/1000:
# Average Loss: 0.000953
# Epoch 740/1000:
# Average Loss: 0.000953
# Epoch 741/1000:
# Average Loss: 0.000953
# Epoch 742/1000:
# Average Loss: 0.000953
# Epoch 743/1000:
# Average Loss: 0.000953
# Epoch 744/1000:
# Average Loss: 0.000953
# Epoch 745/1000:
# Average Loss: 0.000953
# Epoch 746/1000:
# Average Loss: 0.000953
# Epoch 747/1000:
# Average Loss: 0.000953
# Epoch 748/1000:
# Average Loss: 0.000953
# Epoch 749/1000:
# Average Loss: 0.000953
# Epoch 750/1000:
# Average Loss: 0.000953
# Epoch 751/1000:
# Average Loss: 0.000953
# Epoch 752/1000:
# Average Loss: 0.000953
# Epoch 753/1000:
# Average Loss: 0.000953
# Epoch 754/1000:
# Average Loss: 0.000953
# Epoch 755/1000:
# Average Loss: 0.000953
# Epoch 756/1000:
# Average Loss: 0.000953
# Epoch 757/1000:
# Average Loss: 0.000953
# Epoch 758/1000:
# Average Loss: 0.000953
# Epoch 759/1000:
# Average Loss: 0.000953
# Epoch 760/1000:
# Average Loss: 0.000953
# Epoch 761/1000:
# Average Loss: 0.000953
# Epoch 762/1000:
# Average Loss: 0.000953
# Epoch 763/1000:
# Average Loss: 0.000953
# Epoch 764/1000:
# Average Loss: 0.000953
# Epoch 765/1000:
# Average Loss: 0.000953
# Epoch 766/1000:
# Average Loss: 0.000953
# Epoch 767/1000:
# Average Loss: 0.000953
# Epoch 768/1000:
# Average Loss: 0.000953
# Epoch 769/1000:
# Average Loss: 0.000953
# Epoch 770/1000:
# Average Loss: 0.000953
# Epoch 771/1000:
# Average Loss: 0.000953
# Epoch 772/1000:
# Average Loss: 0.000953
# Epoch 773/1000:
# Average Loss: 0.000953
# Epoch 774/1000:
# Average Loss: 0.000953
# Epoch 775/1000:
# Average Loss: 0.000953
# Epoch 776/1000:
# Average Loss: 0.000953
# Epoch 777/1000:
# Average Loss: 0.000953
# Epoch 778/1000:
# Average Loss: 0.000953
# Epoch 779/1000:
# Average Loss: 0.000953
# Epoch 780/1000:
# Average Loss: 0.000953
# Epoch 781/1000:
# Average Loss: 0.000953
# Epoch 782/1000:
# Average Loss: 0.000953
# Epoch 783/1000:
# Average Loss: 0.000953
# Epoch 784/1000:
# Average Loss: 0.000953
# Epoch 785/1000:
# Average Loss: 0.000953
# Epoch 786/1000:
# Average Loss: 0.000953
# Epoch 787/1000:
# Average Loss: 0.000953
# Epoch 788/1000:
# Average Loss: 0.000953
# Epoch 789/1000:
# Average Loss: 0.000953
# Epoch 790/1000:
# Average Loss: 0.000953
# Epoch 791/1000:
# Average Loss: 0.000953
# Epoch 792/1000:
# Average Loss: 0.000953
# Epoch 793/1000:
# Average Loss: 0.000953
# Epoch 794/1000:
# Average Loss: 0.000953
# Epoch 795/1000:
# Average Loss: 0.000953
# Epoch 796/1000:
# Average Loss: 0.000953
# Epoch 797/1000:
# Average Loss: 0.000953
# Epoch 798/1000:
# Average Loss: 0.000953
# Epoch 799/1000:
# Average Loss: 0.000953
# Epoch 800/1000:
# Average Loss: 0.000953
# Epoch 801/1000:
# Average Loss: 0.000953
# Epoch 802/1000:
# Average Loss: 0.000953
# Epoch 803/1000:
# Average Loss: 0.000953
# Epoch 804/1000:
# Average Loss: 0.000953
# Epoch 805/1000:
# Average Loss: 0.000953
# Epoch 806/1000:
# Average Loss: 0.000953
# Epoch 807/1000:
# Average Loss: 0.000953
# Epoch 808/1000:
# Average Loss: 0.000953
# Epoch 809/1000:
# Average Loss: 0.000953
# Epoch 810/1000:
# Average Loss: 0.000953
# Epoch 811/1000:
# Average Loss: 0.000953
# Epoch 812/1000:
# Average Loss: 0.000953
# Epoch 813/1000:
# Average Loss: 0.000953
# Epoch 814/1000:
# Average Loss: 0.000953
# Epoch 815/1000:
# Average Loss: 0.000953
# Epoch 816/1000:
# Average Loss: 0.000953
# Epoch 817/1000:
# Average Loss: 0.000953
# Epoch 818/1000:
# Average Loss: 0.000953
# Epoch 819/1000:
# Average Loss: 0.000953
# Epoch 820/1000:
# Average Loss: 0.000953
# Epoch 821/1000:
# Average Loss: 0.000953
# Epoch 822/1000:
# Average Loss: 0.000953
# Epoch 823/1000:
# Average Loss: 0.000953
# Epoch 824/1000:
# Average Loss: 0.000953
# Epoch 825/1000:
# Average Loss: 0.000953
# Epoch 826/1000:
# Average Loss: 0.000953
# Epoch 827/1000:
# Average Loss: 0.000953
# Epoch 828/1000:
# Average Loss: 0.000953
# Epoch 829/1000:
# Average Loss: 0.000953
# Epoch 830/1000:
# Average Loss: 0.000953
# Epoch 831/1000:
# Average Loss: 0.000953
# Epoch 832/1000:
# Average Loss: 0.000953
# Epoch 833/1000:
# Average Loss: 0.000953
# Epoch 834/1000:
# Average Loss: 0.000953
# Epoch 835/1000:
# Average Loss: 0.000953
# Epoch 836/1000:
# Average Loss: 0.000953
# Epoch 837/1000:
# Average Loss: 0.000953
# Epoch 838/1000:
# Average Loss: 0.000953
# Epoch 839/1000:
# Average Loss: 0.000953
# Epoch 840/1000:
# Average Loss: 0.000953
# Epoch 841/1000:
# Average Loss: 0.000953
# Epoch 842/1000:
# Average Loss: 0.000953
# Epoch 843/1000:
# Average Loss: 0.000953
# Epoch 844/1000:
# Average Loss: 0.000953
# Epoch 845/1000:
# Average Loss: 0.000953
# Epoch 846/1000:
# Average Loss: 0.000953
# Epoch 847/1000:
# Average Loss: 0.000953
# Epoch 848/1000:
# Average Loss: 0.000953
# Epoch 849/1000:
# Average Loss: 0.000953
# Epoch 850/1000:
# Average Loss: 0.000953
# Epoch 851/1000:
# Average Loss: 0.000953
# Epoch 852/1000:
# Average Loss: 0.000953
# Epoch 853/1000:
# Average Loss: 0.000953
# Epoch 854/1000:
# Average Loss: 0.000953
# Epoch 855/1000:
# Average Loss: 0.000953
# Epoch 856/1000:
# Average Loss: 0.000953
# Epoch 857/1000:
# Average Loss: 0.000953
# Epoch 858/1000:
# Average Loss: 0.000953
# Epoch 859/1000:
# Average Loss: 0.000953
# Epoch 860/1000:
# Average Loss: 0.000953
# Epoch 861/1000:
# Average Loss: 0.000953
# Epoch 862/1000:
# Average Loss: 0.000953
# Epoch 863/1000:
# Average Loss: 0.000953
# Epoch 864/1000:
# Average Loss: 0.000953
# Epoch 865/1000:
# Average Loss: 0.000953
# Epoch 866/1000:
# Average Loss: 0.000953
# Epoch 867/1000:
# Average Loss: 0.000953
# Epoch 868/1000:
# Average Loss: 0.000953
# Epoch 869/1000:
# Average Loss: 0.000953
# Epoch 870/1000:
# Average Loss: 0.000953
# Epoch 871/1000:
# Average Loss: 0.000953
# Epoch 872/1000:
# Average Loss: 0.000953
# Epoch 873/1000:
# Average Loss: 0.000953
# Epoch 874/1000:
# Average Loss: 0.000953
# Epoch 875/1000:
# Average Loss: 0.000953
# Epoch 876/1000:
# Average Loss: 0.000953
# Epoch 877/1000:
# Average Loss: 0.000953
# Epoch 878/1000:
# Average Loss: 0.000953
# Epoch 879/1000:
# Average Loss: 0.000953
# Epoch 880/1000:
# Average Loss: 0.000953
# Epoch 881/1000:
# Average Loss: 0.000953
# Epoch 882/1000:
# Average Loss: 0.000953
# Epoch 883/1000:
# Average Loss: 0.000953
# Epoch 884/1000:
# Average Loss: 0.000953
# Epoch 885/1000:
# Average Loss: 0.000953
# Epoch 886/1000:
# Average Loss: 0.000953
# Epoch 887/1000:
# Average Loss: 0.000953
# Epoch 888/1000:
# Average Loss: 0.000953
# Epoch 889/1000:
# Average Loss: 0.000953
# Epoch 890/1000:
# Average Loss: 0.000953
# Epoch 891/1000:
# Average Loss: 0.000953
# Epoch 892/1000:
# Average Loss: 0.000953
# Epoch 893/1000:
# Average Loss: 0.000953
# Epoch 894/1000:
# Average Loss: 0.000953
# Epoch 895/1000:
# Average Loss: 0.000953
# Epoch 896/1000:
# Average Loss: 0.000953
# Epoch 897/1000:
# Average Loss: 0.000953
# Epoch 898/1000:
# Average Loss: 0.000953
# Epoch 899/1000:
# Average Loss: 0.000953
# Epoch 900/1000:
# Average Loss: 0.000953
# Epoch 901/1000:
# Average Loss: 0.000953
# Epoch 902/1000:
# Average Loss: 0.000953
# Epoch 903/1000:
# Average Loss: 0.000953
# Epoch 904/1000:
# Average Loss: 0.000953
# Epoch 905/1000:
# Average Loss: 0.000953
# Epoch 906/1000:
# Average Loss: 0.000953
# Epoch 907/1000:
# Average Loss: 0.000953
# Epoch 908/1000:
# Average Loss: 0.000953
# Epoch 909/1000:
# Average Loss: 0.000953
# Epoch 910/1000:
# Average Loss: 0.000953
# Epoch 911/1000:
# Average Loss: 0.000953
# Epoch 912/1000:
# Average Loss: 0.000953
# Epoch 913/1000:
# Average Loss: 0.000953
# Epoch 914/1000:
# Average Loss: 0.000953
# Epoch 915/1000:
# Average Loss: 0.000953
# Epoch 916/1000:
# Average Loss: 0.000953
# Epoch 917/1000:
# Average Loss: 0.000953
# Epoch 918/1000:
# Average Loss: 0.000953
# Epoch 919/1000:
# Average Loss: 0.000953
# Epoch 920/1000:
# Average Loss: 0.000953
# Epoch 921/1000:
# Average Loss: 0.000953
# Epoch 922/1000:
# Average Loss: 0.000953
# Epoch 923/1000:
# Average Loss: 0.000953
# Epoch 924/1000:
# Average Loss: 0.000953
# Epoch 925/1000:
# Average Loss: 0.000953
# Epoch 926/1000:
# Average Loss: 0.000953
# Epoch 927/1000:
# Average Loss: 0.000953
# Epoch 928/1000:
# Average Loss: 0.000953
# Epoch 929/1000:
# Average Loss: 0.000953
# Epoch 930/1000:
# Average Loss: 0.000953
# Epoch 931/1000:
# Average Loss: 0.000953
# Epoch 932/1000:
# Average Loss: 0.000953
# Epoch 933/1000:
# Average Loss: 0.000953
# Epoch 934/1000:
# Average Loss: 0.000953
# Epoch 935/1000:
# Average Loss: 0.000953
# Epoch 936/1000:
# Average Loss: 0.000953
# Epoch 937/1000:
# Average Loss: 0.000953
# Epoch 938/1000:
# Average Loss: 0.000953
# Epoch 939/1000:
# Average Loss: 0.000953
# Epoch 940/1000:
# Average Loss: 0.000953
# Epoch 941/1000:
# Average Loss: 0.000953
# Epoch 942/1000:
# Average Loss: 0.000953
# Epoch 943/1000:
# Average Loss: 0.000953
# Epoch 944/1000:
# Average Loss: 0.000953
# Epoch 945/1000:
# Average Loss: 0.000953
# Epoch 946/1000:
# Average Loss: 0.000953
# Epoch 947/1000:
# Average Loss: 0.000953
# Epoch 948/1000:
# Average Loss: 0.000953
# Epoch 949/1000:
# Average Loss: 0.000953
# Epoch 950/1000:
# Average Loss: 0.000953
# Epoch 951/1000:
# Average Loss: 0.000953
# Epoch 952/1000:
# Average Loss: 0.000953
# Epoch 953/1000:
# Average Loss: 0.000953
# Epoch 954/1000:
# Average Loss: 0.000953
# Epoch 955/1000:
# Average Loss: 0.000953
# Epoch 956/1000:
# Average Loss: 0.000953
# Epoch 957/1000:
# Average Loss: 0.000953
# Epoch 958/1000:
# Average Loss: 0.000953
# Epoch 959/1000:
# Average Loss: 0.000953
# Epoch 960/1000:
# Average Loss: 0.000953
# Epoch 961/1000:
# Average Loss: 0.000953
# Epoch 962/1000:
# Average Loss: 0.000953
# Epoch 963/1000:
# Average Loss: 0.000953
# Epoch 964/1000:
# Average Loss: 0.000953
# Epoch 965/1000:
# Average Loss: 0.000953
# Epoch 966/1000:
# Average Loss: 0.000953
# Epoch 967/1000:
# Average Loss: 0.000953
# Epoch 968/1000:
# Average Loss: 0.000953
# Epoch 969/1000:
# Average Loss: 0.000953
# Epoch 970/1000:
# Average Loss: 0.000953
# Epoch 971/1000:
# Average Loss: 0.000953
# Epoch 972/1000:
# Average Loss: 0.000953
# Epoch 973/1000:
# Average Loss: 0.000953
# Epoch 974/1000:
# Average Loss: 0.000953
# Epoch 975/1000:
# Average Loss: 0.000953
# Epoch 976/1000:
# Average Loss: 0.000953
# Epoch 977/1000:
# Average Loss: 0.000953
# Epoch 978/1000:
# Average Loss: 0.000953
# Epoch 979/1000:
# Average Loss: 0.000953
# Epoch 980/1000:
# Average Loss: 0.000953
# Epoch 981/1000:
# Average Loss: 0.000953
# Epoch 982/1000:
# Average Loss: 0.000953
# Epoch 983/1000:
# Average Loss: 0.000953
# Epoch 984/1000:
# Average Loss: 0.000953
# Epoch 985/1000:
# Average Loss: 0.000953
# Epoch 986/1000:
# Average Loss: 0.000953
# Epoch 987/1000:
# Average Loss: 0.000953
# Epoch 988/1000:
# Average Loss: 0.000953
# Epoch 989/1000:
# Average Loss: 0.000953
# Epoch 990/1000:
# Average Loss: 0.000953
# Epoch 991/1000:
# Average Loss: 0.000953
# Epoch 992/1000:
# Average Loss: 0.000953
# Epoch 993/1000:
# Average Loss: 0.000953
# Epoch 994/1000:
# Average Loss: 0.000953
# Epoch 995/1000:
# Average Loss: 0.000953
# Epoch 996/1000:
# Average Loss: 0.000953
# Epoch 997/1000:
# Average Loss: 0.000953
# Epoch 998/1000:
# Average Loss: 0.000953
# Epoch 999/1000:
# Average Loss: 0.000953
# Training finished.

# %% [markdown]
# Task 05 - Visualization

# %%
# plot training progress 
# average loss per epoch
plt.scatter(np.arange(num_epochs), losses)
plt.xlabel('epoch')
plt.ylabel('average loss')

plt.show()
